# %%
from google.colab import drive
drive.mount('/content/drive/')

# %%
import os
#os.chdir("content")
os.chdir("drive")
os.chdir("My Drive")
os.chdir("Emotion Timeline Formation for Each Subject in a Video")
os.chdir("src")

# %%
# !chmod 774 install_required_modules.sh

# %%
# !./install_required_modules.sh

# %%
# !python video_emotion_rgb.py -f 15 -out './first_out' --save_embed -t 0 20000 -v '../../Facial Emotion Recognition/Diego_Luna_Interview.mp4'
